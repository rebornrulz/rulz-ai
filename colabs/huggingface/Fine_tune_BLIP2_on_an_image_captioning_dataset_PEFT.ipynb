# %% [markdown]
# # Fine-tune BLIP using Hugging Face `transformers`, `datasets`, `peft` 🤗 and `bitsandbytes`
#
# Let's leverage recent advances from Parameter Efficient Fine-Tuning methods to fine-tune a large image to text model! We will show through this tutorial that it is possible to fine-tune a 3B scale model (~6GB in half-precision)
#
# Here we will use a dummy dataset of [football players](https://huggingface.co/datasets/ybelkada/football-dataset) ⚽ that is uploaded on the Hub. The images have been manually selected together with the captions.
# Check the 🤗 [documentation](https://huggingface.co/docs/datasets/image_dataset) on how to create and upload your own image-text dataset.

# %% [markdown]
# ## Set-up environment

# %%
# !pip install -q git+https://github.com/huggingface/peft.git transformers bitsandbytes datasets

# %% [markdown]
# ## Load the image captioning dataset
#
# Let's load the image captioning dataset, you just need few lines of code for that.

# %%
from datasets import load_dataset 

dataset = load_dataset("ybelkada/football-dataset", split="train")
# Out:
# Downloading readme:   0%|          | 0.00/371 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/2.07M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/6 [00:00<?, ? examples/s]

# %% [markdown]
# Let's retrieve the caption of the first example:

# %%
dataset[0]["text"]
# Out:
# "Benzema after Real Mardid's win against PSG"

# %% [markdown]
# And the corresponding image

# %%
dataset[0]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=722x360>

# %% [markdown]
# ## Create PyTorch Dataset

# %% [markdown]
# Let's define below the dataset as well as the data collator!

# %%
from torch.utils.data import Dataset, DataLoader

class ImageCaptioningDataset(Dataset):
    def __init__(self, dataset, processor):
        self.dataset = dataset
        self.processor = processor

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        item = self.dataset[idx]
        encoding = self.processor(images=item["image"], padding="max_length", return_tensors="pt")
        # remove batch dimension
        encoding = {k: v.squeeze() for k, v in encoding.items()}
        encoding["text"] = item["text"]
        return encoding

def collate_fn(batch):
    # pad the input_ids and attention_mask
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# %% [markdown]
# ## Load model and processor

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", device_map="auto", load_in_8bit=True)
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/904 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/7.05k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/rulz-ai/Rulz-AI/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 14 line 4
#       <a href='vscode-notebook-cell:/Users/rulz-ai/Rulz-AI/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> from transformers import AutoProcessor, Blip2ForConditionalGeneration
#       <a href='vscode-notebook-cell:/Users/rulz-ai/Rulz-AI/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
# ----> <a href='vscode-notebook-cell:/Users/rulz-ai/Rulz-AI/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> model = Blip2ForConditionalGeneration.from_pretrained("ybelkada/blip2-opt-2.7b-fp16-sharded", device_map="auto", load_in_8bit=True)
#
# File ~/Library/Python/3.9/lib/python/site-packages/transformers/modeling_utils.py:2714, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2712 if load_in_8bit or load_in_4bit:
#    2713     if not (is_accelerate_available() and is_bitsandbytes_available()):
# -> 2714         raise ImportError(
#    2715             "Using `load_in_8bit=True` requires Accelerate: `pip install accelerate` and the latest version of"
#    2716             " bitsandbytes `pip install -i https://test.pypi.org/simple/ bitsandbytes` or"
#    2717             " pip install bitsandbytes` "
#    2718         )
#    2720     if torch_dtype is None:
#    2721         # We force the `dtype` to be float16, this is a requirement from `bitsandbytes`
#    2722         logger.info(
#    2723             f"Overriding torch_dtype={torch_dtype} with `torch_dtype=torch.float16` due to "
#    2724             "requirements of `bitsandbytes` to enable model loading in 8-bit or 4-bit. "
#    2725             "Pass your own torch_dtype to specify the dtype of the remaining non-linear layers or pass"
#    2726             " torch_dtype=torch.float16 to remove this warning."
#    2727         )
#
# ImportError: Using `load_in_8bit=True` requires Accelerate: `pip install accelerate` and the latest version of bitsandbytes `pip install -i https://test.pypi.org/simple/ bitsandbytes` or pip install bitsandbytes`

# %% [markdown]
# Next we define our `LoraConfig` object. We explicitly tell

# %%
from peft import LoraConfig, get_peft_model

# Let's define the LoraConfig
config = LoraConfig(
    r=16,
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=["q_proj", "k_proj"]
)

model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# c:\Users\rebor\miniconda3\lib\site-packages\bitsandbytes\cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\AI\rulz-ai\colabs\huggingface\Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 16 line 1
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> # Let's define the LoraConfig
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> config = LoraConfig(
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     r=16,
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>     lora_alpha=32,
#    (...)
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>     target_modules=["q_proj", "k_proj"]
#      <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> )
# ---> <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> model = get_peft_model(model, config)
#      <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a> model.print_trainable_parameters()
#
# NameError: name 'model' is not defined

# %% [markdown]
# Now that we have loaded the processor, let's load the dataset and the dataloader:

# %%
train_dataset = ImageCaptioningDataset(dataset, processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=3, collate_fn=collate_fn)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Let's train the model! Run the simply the cell below for training the model

# %%
import torch

optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)

device = "cuda" if torch.cuda.is_available() else "cpu"

model.train()

for epoch in range(200):
  print("Epoch:", epoch)
  for idx, batch in enumerate(train_dataloader):
    input_ids = batch.pop("input_ids").to(device)
    pixel_values = batch.pop("pixel_values").to(device, torch.float16)

    outputs = model(input_ids=input_ids,
                    pixel_values=pixel_values,
                    labels=input_ids)
    
    loss = outputs.loss

    print("Loss:", loss.item())

    loss.backward()

    optimizer.step()
    optimizer.zero_grad()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\AI\rulz-ai\colabs\huggingface\Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> device = "cuda" if torch.cuda.is_available() else "cpu"
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a> model.train()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Inference

# %% [markdown]
# Let's check the results on our train dataset

# %%
# load image
example = dataset[0]
image = example["image"]
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=722x360>

# %%
# prepare image for the model
inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
pixel_values = inputs.pixel_values

generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(generated_caption)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\AI\rulz-ai\colabs\huggingface\Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> # prepare image for the model
# ----> <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> pixel_values = inputs.pixel_values
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
#
# NameError: name 'device' is not defined

# %% [markdown]
# ## Push to Hub

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.push_to_hub("ybelkada/blip2-opt-2.7b-football-captions-adapters")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\AI\rulz-ai\colabs\huggingface\Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> model.push_to_hub("ybelkada/blip2-opt-2.7b-football-captions-adapters")
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Load from the Hub

# %% [markdown]
# Once trained you can push the model and processor on the Hub to use them later.
# Meanwhile you can play with the model that we have fine-tuned!
# Please restart the runtime to run the cell below!

# %%
from transformers import Blip2ForConditionalGeneration, AutoProcessor
from peft import PeftModel, PeftConfig

peft_model_id = "ybelkada/blip2-opt-2.7b-football-captions-adapters"
config = PeftConfig.from_pretrained(peft_model_id)

model = Blip2ForConditionalGeneration.from_pretrained(config.base_model_name_or_path, load_in_8bit=True, device_map="auto")
model = PeftModel.from_pretrained(model, peft_model_id)

processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
# Out:
# Downloading (…)/adapter_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# d:\AI\rulz-ai\colabs\huggingface\Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb Cell 31 line 7
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X42sZmlsZQ%3D%3D?line=3'>4</a> peft_model_id = "ybelkada/blip2-opt-2.7b-football-captions-adapters"
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X42sZmlsZQ%3D%3D?line=4'>5</a> config = PeftConfig.from_pretrained(peft_model_id)
# ----> <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X42sZmlsZQ%3D%3D?line=6'>7</a> model = Blip2ForConditionalGeneration.from_pretrained(config.base_model_name_or_path, load_in_8bit=True, device_map="auto")
#       <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X42sZmlsZQ%3D%3D?line=7'>8</a> model = PeftModel.from_pretrained(model, peft_model_id)
#      <a href='vscode-notebook-cell:/d%3A/AI/rulz-ai/colabs/huggingface/Fine_tune_BLIP2_on_an_image_captioning_dataset_PEFT.ipynb#X42sZmlsZQ%3D%3D?line=9'>10</a> processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
#
# File c:\Users\rebor\miniconda3\lib\site-packages\transformers\modeling_utils.py:2596, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2594 if load_in_8bit or load_in_4bit:
#    2595     if not (is_accelerate_available() and is_bitsandbytes_available()):
# -> 2596         raise ImportError(
#    2597             "Using `load_in_8bit=True` requires Accelerate: `pip install accelerate` and the latest version of"
#    2598             " bitsandbytes `pip install -i https://test.pypi.org/simple/ bitsandbytes` or"
#    2599             " pip install bitsandbytes` "
#    2600         )
#    2602     if torch_dtype is None:
#    2603         # We force the `dtype` to be float16, this is a requirement from `bitsandbytes`
#    2604         logger.info(
#    2605             f"Overriding torch_dtype={torch_dtype} with `torch_dtype=torch.float16` due to "
#    2606             "requirements of `bitsandbytes` to enable model loading in 8-bit or 4-bit. "
#    2607             "Pass your own torch_dtype to specify the dtype of the remaining non-linear layers or pass"
#    2608             " torch_dtype=torch.float16 to remove this warning."
#    2609         )
#
# ImportError: Using `load_in_8bit=True` requires Accelerate: `pip install accelerate` and the latest version of bitsandbytes `pip install -i https://test.pypi.org/simple/ bitsandbytes` or pip install bitsandbytes`

# %% [markdown]
# Let's check the results on our train dataset!

# %%
import torch
from matplotlib import pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"

fig = plt.figure(figsize=(18, 14))

# prepare image for the model
for i, example in enumerate(dataset):
  image = example["image"]
  inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
  pixel_values = inputs.pixel_values

  generated_ids = model.generate(pixel_values=pixel_values, max_length=25)
  generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
  fig.add_subplot(2, 3, i+1)
  plt.imshow(image)
  plt.axis("off")
  plt.title(f"Generated caption: {generated_caption}")
