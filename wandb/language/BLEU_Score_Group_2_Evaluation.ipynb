# %% [markdown]
# <a href="https://colab.research.google.com/github/rebornrulz/rulz-ai/blob/main/wandb/lamguagw/BLEU_Score_Group_2_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Chatbot BLEU Evaluation Group 2
# Out:
#   File "<ipython-input-1-73d09387586b>", line 1
#     Chatbot BLEU Evaluation Group 2
#             ^
# SyntaxError: invalid syntax

# %%
#Bleu Evaluation Group 2 1-gram & 2-gram
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
#r answer similar to Questionaire given to Human evaluators
r1 = [['hi']]
r2 = [['jaku', 'adjektif', 'tu', 'diguna', 'lebuh', 'deka', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']]
r3 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'manah']]
r4 = [['jaku', 'pengawa', 'dikena', 'ba', 'pugu', 'rambai', 'jaku', 'pengawa']]
r5 = [['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']]
r6 = [['sama', 'sama']]
r7 = [['okay', 'sama', 'sama']]
r8 = [['bahasa', 'iban', 'ngena', 'dua', 'puluh', 'enam', 'urup', 'roman', 'baka', 'bahasa', 'melayu']]
r9 = [['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']]
r10 = [['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']]
r11 = [['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nama', 'orang', 'baka', 'Listra']]
r12 = [['minta', 'uji', 'enggau', 'anang']]
r13 = [['nuan', 'ka', 'nemu', 'bengkah', 'jaku', 'nama', 'ni']]
r14 = [['Bye']]
r15 = [['antara', 'atur', 'sepil', 'jaku', 'iban', 'iya', 'atur', 'nulis', 'urat', 'jaku', 'atur', 'nulis', 'penambah', 'homograf', 'enggau', 'homonim']]
r16 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']]
r17 = [['manah', 'amat', 'gamal', 'indu', 'nya']]
r18 = [['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']]
r19 = [['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']]
r20 = [['jaku', 'tugas', 'semina', 'beguna', 'nyadika', 'sanding', 'jaku', 'nama']]
r21 = [['sama', 'sama']]
r22 = [['hi', 'mega']]
r23 = [['aku', 'nitihka', 'nuan', 'aja']]
r24 = [['aku', 'digaga', 'maya', 'taun', '2021']]
r25 = [['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']]
r26 = [['ilomilo', 'billie', 'ellish']]
r27 = [['naka', 'tu', 'aja', 'randau', 'tua']]
r28 = [['hello']]
r29 = [['aku', 'nitihka', 'nuan', 'aja']]
r30 = [['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']]
r31 = [['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']]
r32 = [['aku', 'tusah', 'ati', 'enti', 'nuan', 'tusah', 'ati']]
r33 = [['aram', 'meh']]
r34 = [['ok', 'bye']]
#Answer generated by chatbot
c1 = ['yoohoo']
c2 = ['jaku', 'adjektif', 'tu', 'dikena', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']
c3 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c4 = ['raban', 'jaku', 'pengawa', 'tu', 'leka', 'jaku', 'ti', 'nyadi', 'pugu', 'ba', 'rambai', 'jaku', 'pengawa']
c5 = ['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']
c6 = ['sama', 'sama']
c7 = ['Sama', 'sama']
c8 = ['antara', 'atur', 'sepil', 'jaku', 'iban', 'nya', 'nya', 'atur', 'nulih', 'urat', 'jaku', 'atur', 'nulih', 'penambah', 'homograf', 'enggau', 'homonim']
c9 = ['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']
c10 = ['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']
c11 = ['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nya', 'nama', 'orang', 'baka', 'listra']
c12 = ['bengkah', 'jaku', 'nama', 'ti', 'bisi', 'iya', 'nya', 'jaku', 'nama', 'tetap', 'jaku', 'nama', 'rama', 'enggau', 'jaku', 'ganti', 'nama']
c13 = ['anang', 'belagu', 'rerauh']
c14 = ['bye', 'bye']
c15 = ['jaku', 'adjektif', 'tu', 'dikena', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']
c16 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c17 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c18 = ['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']
c19 = ['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']
c20 = ['aku', 'tugas', 'ulih', 'mai', 'reti', 'enti', 'dikena', 'dalam', 'rambai', 'jaku']
c21 = ['sama', 'sama']
c22 = ['oh', 'gerai', 'nuan']
c23 = ['ni', 'ko', 'nuan']
c24 = ['aku', 'digaga', 'maya', 'taun', '2021', 'Mei']
c25 = ['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']
c26 = ['backyard', 'boy', 'claire', 'rosinkranz']
c27 = ['hm']
c28 = ['oh', 'nadai', 'ngawa', 'nuan']
c29 = ['aku', 'nitihka', 'nuan', 'aja']
c30 = ['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']
c31 = ['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']
c32 = ['aku', 'nadai', 'asai', 'ati', 'laban', 'aku', 'bot']
c33 = ['bersyukur', 'meh', 'nuan', 'nya', 'mensia']
c34 = ['ila', 'berandau', 'baru']
smoothie = SmoothingFunction().method1

# 1 gram
s1 = sentence_bleu(r1, c1, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s2 = sentence_bleu(r2, c2, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s3 = sentence_bleu(r3, c3, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s4 = sentence_bleu(r4, c4, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s5 = sentence_bleu(r5, c5, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s6 = sentence_bleu(r6, c6, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s7 = sentence_bleu(r7, c7, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s8 = sentence_bleu(r8, c8, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s9 = sentence_bleu(r9, c9, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s10 = sentence_bleu(r10, c10, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s11 = sentence_bleu(r11, c11, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s12 = sentence_bleu(r12, c12, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s13 = sentence_bleu(r13, c13, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s14 = sentence_bleu(r14, c14, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s15 = sentence_bleu(r15, c15, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s16 = sentence_bleu(r16, c16, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s17 = sentence_bleu(r17, c17, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s18 = sentence_bleu(r18, c18, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s19 = sentence_bleu(r19, c19, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s20 = sentence_bleu(r20, c20, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s21 = sentence_bleu(r21, c21, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s22 = sentence_bleu(r22, c22, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s23 = sentence_bleu(r23, c23, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s24 = sentence_bleu(r24, c24, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s25 = sentence_bleu(r25, c25, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s26 = sentence_bleu(r26, c26, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s27 = sentence_bleu(r27, c27, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s28 = sentence_bleu(r28, c28, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s29 = sentence_bleu(r29, c29, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s30 = sentence_bleu(r30, c30, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s31 = sentence_bleu(r31, c31, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s32 = sentence_bleu(r32, c32, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s33 = sentence_bleu(r33, c33, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s34 = sentence_bleu(r34, c34, smoothing_function=smoothie, weights=(1, 0, 0, 0))
# 2 gram
s11 = sentence_bleu(r1, c1, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s21 = sentence_bleu(r2, c2, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s31 = sentence_bleu(r3, c3, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s41 = sentence_bleu(r4, c4, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s51 = sentence_bleu(r5, c5, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s61 = sentence_bleu(r6, c6, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s71 = sentence_bleu(r7, c7, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s81 = sentence_bleu(r8, c8, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s91 = sentence_bleu(r9, c9, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s101 = sentence_bleu(r10, c10, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s111 = sentence_bleu(r11, c11, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s121 = sentence_bleu(r12, c12, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s131 = sentence_bleu(r13, c13, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s141 = sentence_bleu(r14, c14, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s151 = sentence_bleu(r15, c15, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s161 = sentence_bleu(r16, c16, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s171 = sentence_bleu(r17, c17, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s181 = sentence_bleu(r18, c18, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s191 = sentence_bleu(r19, c19, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s201 = sentence_bleu(r20, c20, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s211 = sentence_bleu(r21, c21, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s221 = sentence_bleu(r22, c22, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s231 = sentence_bleu(r23, c23, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s241 = sentence_bleu(r24, c24, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s251 = sentence_bleu(r25, c25, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s261 = sentence_bleu(r26, c26, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s271 = sentence_bleu(r27, c27, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s281 = sentence_bleu(r28, c28, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s291 = sentence_bleu(r29, c29, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s301 = sentence_bleu(r30, c30, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s311 = sentence_bleu(r31, c31, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s321 = sentence_bleu(r32, c32, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s331 = sentence_bleu(r33, c33, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s341 = sentence_bleu(r34, c34, smoothing_function=smoothie, weights=(0, 1, 0, 0))

# 1 gram -----------------------------------------------------------------------------------------------------------------------------------------------------------
sa = s1 + s2 + s3 + s4 + s5 + s6 + s7 + s8 + s9 + s10 + s11 + s12 + s13 + s14 + s15 + s16 + s17
sb = s18 + s19 + s20 + s21 + s22 + s23 + s24 + s25 + s26 + s27 + s28 + s29 + s30 + s31 + s32 + s33 + s34
s = (sa + sb)/34

# 2 gram ------------------------------------------------------------------------------------------------------------------------------------------------------------
sa1 = s11 + s21 + s31 + s41 + s51 + s61 + s71 + s81 + s91 + s101 + s111 + s121 + s131 + s141 + s151 + s161 + s171
sb1 = s181 + s191 + s201 + s211 + s221 + s231 + s241 + s251 + s261 + s271 + s281 + s291 + s301 + s311 + s321 + s331 + s341
s2gram = (sa1 + sb1)/34
# print('Bleu Score: %f' % score)
print('Bleu Score 1-Gram Group 2 MAL: %f' % s)
print('Bleu Score 2-Gram Group 2 MAL: %f' % s2gram)
# Out:
# Bleu Score 1-Gram Group 2 MAL: 0.469559
# Bleu Score 2-Gram Group 2 MAL: 0.451021

# %%
#Bleu Evaluation Group 2
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
#r answer similar to Questionaire given to Human evaluators
r1 = [['hi']]
r2 = [['jaku', 'adjektif', 'tu', 'diguna', 'lebuh', 'deka', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']]
r3 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'manah']]
r4 = [['jaku', 'pengawa', 'dikena', 'ba', 'pugu', 'rambai', 'jaku', 'pengawa']]
r5 = [['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']]
r6 = [['sama', 'sama']]
r7 = [['okay', 'sama', 'sama']]
r8 = [['bahasa', 'iban', 'ngena', 'dua', 'puluh', 'enam', 'urup', 'roman', 'baka', 'bahasa', 'melayu']]
r9 = [['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']]
r10 = [['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']]
r11 = [['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nama', 'orang', 'baka', 'Listra']]
r12 = [['minta', 'uji', 'enggau', 'anang']]
r13 = [['nuan', 'ka', 'nemu', 'bengkah', 'jaku', 'nama', 'ni']]
r14 = [['Bye']]
r15 = [['antara', 'atur', 'sepil', 'jaku', 'iban', 'iya', 'atur', 'nulis', 'urat', 'jaku', 'atur', 'nulis', 'penambah', 'homograf', 'enggau', 'homonim']]
r16 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']]
r17 = [['manah', 'amat', 'gamal', 'indu', 'nya']]
r18 = [['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']]
r19 = [['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']]
r20 = [['jaku', 'tugas', 'semina', 'beguna', 'nyadika', 'sanding', 'jaku', 'nama']]
r21 = [['sama', 'sama']]
r22 = [['hi', 'mega']]
r23 = [['aku', 'nitihka', 'nuan', 'aja']]
r24 = [['aku', 'digaga', 'maya', 'taun', '2021']]
r25 = [['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']]
r26 = [['ilomilo', 'billie', 'ellish']]
r27 = [['naka', 'tu', 'aja', 'randau', 'tua']]
r28 = [['hello']]
r29 = [['aku', 'nitihka', 'nuan', 'aja']]
r30 = [['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']]
r31 = [['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']]
r32 = [['aku', 'tusah', 'ati', 'enti', 'nuan', 'tusah', 'ati']]
r33 = [['aram', 'meh']]
r34 = [['ok', 'bye']]
#Answer generated by chatbot
c1 = ['yoohoo']
c2 = ['jaku', 'adjektif', 'tu', 'dikena', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']
c3 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c4 = ['raban', 'jaku', 'pengawa', 'tu', 'leka', 'jaku', 'ti', 'nyadi', 'pugu', 'ba', 'rambai', 'jaku', 'pengawa']
c5 = ['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']
c6 = ['sama', 'sama']
c7 = ['Sama', 'sama']
c8 = ['antara', 'atur', 'sepil', 'jaku', 'iban', 'nya', 'nya', 'atur', 'nulih', 'urat', 'jaku', 'atur', 'nulih', 'penambah', 'homograf', 'enggau', 'homonim']
c9 = ['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']
c10 = ['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']
c11 = ['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nya', 'nama', 'orang', 'baka', 'listra']
c12 = ['bengkah', 'jaku', 'nama', 'ti', 'bisi', 'iya', 'nya', 'jaku', 'nama', 'tetap', 'jaku', 'nama', 'rama', 'enggau', 'jaku', 'ganti', 'nama']
c13 = ['anang', 'belagu', 'rerauh']
c14 = ['bye', 'bye']
c15 = ['jaku', 'adjektif', 'tu', 'dikena', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']
c16 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c17 = ['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']
c18 = ['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']
c19 = ['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']
c20 = ['aku', 'tugas', 'ulih', 'mai', 'reti', 'enti', 'dikena', 'dalam', 'rambai', 'jaku']
c21 = ['sama', 'sama']
c22 = ['oh', 'gerai', 'nuan']
c23 = ['ni', 'ko', 'nuan']
c24 = ['aku', 'digaga', 'maya', 'taun', '2021', 'Mei']
c25 = ['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']
c26 = ['backyard', 'boy', 'claire', 'rosinkranz']
c27 = ['hm']
c28 = ['oh', 'nadai', 'ngawa', 'nuan']
c29 = ['aku', 'nitihka', 'nuan', 'aja']
c30 = ['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']
c31 = ['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']
c32 = ['aku', 'nadai', 'asai', 'ati', 'laban', 'aku', 'bot']
c33 = ['bersyukur', 'meh', 'nuan', 'nya', 'mensia']
c34 = ['ila', 'berandau', 'baru']
smoothie = SmoothingFunction().method1

# 3 gram Bleu
s1 = sentence_bleu(r1, c1, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s2 = sentence_bleu(r2, c2, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s3 = sentence_bleu(r3, c3, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s4 = sentence_bleu(r4, c4, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s5 = sentence_bleu(r5, c5, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s6 = sentence_bleu(r6, c6, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s7 = sentence_bleu(r7, c7, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s8 = sentence_bleu(r8, c8, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s9 = sentence_bleu(r9, c9, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s10 = sentence_bleu(r10, c10, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s11 = sentence_bleu(r11, c11, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s12 = sentence_bleu(r12, c12, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s13 = sentence_bleu(r13, c13, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s14 = sentence_bleu(r14, c14, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s15 = sentence_bleu(r15, c15, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s16 = sentence_bleu(r16, c16, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s17 = sentence_bleu(r17, c17, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s18 = sentence_bleu(r18, c18, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s19 = sentence_bleu(r19, c19, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s20 = sentence_bleu(r20, c20, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s21 = sentence_bleu(r21, c21, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s22 = sentence_bleu(r22, c22, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s23 = sentence_bleu(r23, c23, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s24 = sentence_bleu(r24, c24, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s25 = sentence_bleu(r25, c25, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s26 = sentence_bleu(r26, c26, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s27 = sentence_bleu(r27, c27, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s28 = sentence_bleu(r28, c28, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s29 = sentence_bleu(r29, c29, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s30 = sentence_bleu(r30, c30, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s31 = sentence_bleu(r31, c31, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s32 = sentence_bleu(r32, c32, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s33 = sentence_bleu(r33, c33, smoothing_function=smoothie, weights=(0, 0, 1, 0))
s34 = sentence_bleu(r34, c34, smoothing_function=smoothie, weights=(0, 0, 1, 0))
# 4 gram
s11 = sentence_bleu(r1, c1, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s21 = sentence_bleu(r2, c2, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s31 = sentence_bleu(r3, c3, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s41 = sentence_bleu(r4, c4, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s51 = sentence_bleu(r5, c5, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s61 = sentence_bleu(r6, c6, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s71 = sentence_bleu(r7, c7, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s81 = sentence_bleu(r8, c8, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s91 = sentence_bleu(r9, c9, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s101 = sentence_bleu(r10, c10, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s111 = sentence_bleu(r11, c11, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s121 = sentence_bleu(r12, c12, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s131 = sentence_bleu(r13, c13, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s141 = sentence_bleu(r14, c14, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s151 = sentence_bleu(r15, c15, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s161 = sentence_bleu(r16, c16, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s171 = sentence_bleu(r17, c17, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s181 = sentence_bleu(r18, c18, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s191 = sentence_bleu(r19, c19, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s201 = sentence_bleu(r20, c20, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s211 = sentence_bleu(r21, c21, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s221 = sentence_bleu(r22, c22, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s231 = sentence_bleu(r23, c23, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s241 = sentence_bleu(r24, c24, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s251 = sentence_bleu(r25, c25, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s261 = sentence_bleu(r26, c26, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s271 = sentence_bleu(r27, c27, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s281 = sentence_bleu(r28, c28, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s291 = sentence_bleu(r29, c29, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s301 = sentence_bleu(r30, c30, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s311 = sentence_bleu(r31, c31, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s321 = sentence_bleu(r32, c32, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s331 = sentence_bleu(r33, c33, smoothing_function=smoothie, weights=(0, 0, 0, 1))
s341 = sentence_bleu(r34, c34, smoothing_function=smoothie, weights=(0, 0, 0, 1))

# 1 gram -----------------------------------------------------------------------------------------------------------------------------------------------------------
sa = s1 + s2 + s3 + s4 + s5 + s6 + s7 + s8 + s9 + s10 + s11 + s12 + s13 + s14 + s15 + s16 + s17
sb = s18 + s19 + s20 + s21 + s22 + s23 + s24 + s25 + s26 + s27 + s28 + s29 + s30 + s31 + s32 + s33 + s34
s = (sa + sb)/34

# 2 gram ------------------------------------------------------------------------------------------------------------------------------------------------------------
sa1 = s11 + s21 + s31 + s41 + s51 + s61 + s71 + s81 + s91 + s101 + s111 + s121 + s131 + s141 + s151 + s161 + s171
sb1 = s181 + s191 + s201 + s211 + s221 + s231 + s241 + s251 + s261 + s271 + s281 + s291 + s301 + s311 + s321 + s331 + s341
s2gram = (sa1 + sb1)/34
# print('Bleu Score: %f' % score)
print('Bleu Score 3-Gram Group 2 MAL: %f' % s)
print('Bleu Score 4-Gram Group 2 MAL: %f' % s2gram)
# Out:
# Bleu Score 3-Gram Group 2 MAL: 0.366277
# Bleu Score 4-Gram Group 2 MAL: 0.366113

# %%
#Bleu Evaluation Group 2 1-gram & 2-gram
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
#r answer similar to Questionaire given to Human evaluators
r1 = [['hi']]
r2 = [['jaku', 'adjektif', 'tu', 'diguna', 'lebuh', 'deka', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']]
r3 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'manah']]
r4 = [['jaku', 'pengawa', 'dikena', 'ba', 'pugu', 'rambai', 'jaku', 'pengawa']]
r5 = [['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']]
r6 = [['sama', 'sama']]
r7 = [['okay', 'sama', 'sama']]
r8 = [['bahasa', 'iban', 'ngena', 'dua', 'puluh', 'enam', 'urup', 'roman', 'baka', 'bahasa', 'melayu']]
r9 = [['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']]
r10 = [['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']]
r11 = [['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nama', 'orang', 'baka', 'Listra']]
r12 = [['minta', 'uji', 'enggau', 'anang']]
r13 = [['nuan', 'ka', 'nemu', 'bengkah', 'jaku', 'nama', 'ni']]
r14 = [['Bye']]
r15 = [['antara', 'atur', 'sepil', 'jaku', 'iban', 'iya', 'atur', 'nulis', 'urat', 'jaku', 'atur', 'nulis', 'penambah', 'homograf', 'enggau', 'homonim']]
r16 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']]
r17 = [['manah', 'amat', 'gamal', 'indu', 'nya']]
r18 = [['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']]
r19 = [['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']]
r20 = [['jaku', 'tugas', 'semina', 'beguna', 'nyadika', 'sanding', 'jaku', 'nama']]
r21 = [['sama', 'sama']]
r22 = [['hi', 'mega']]
r23 = [['aku', 'nitihka', 'nuan', 'aja']]
r24 = [['aku', 'digaga', 'maya', 'taun', '2021']]
r25 = [['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']]
r26 = [['ilomilo', 'billie', 'ellish']]
r27 = [['naka', 'tu', 'aja', 'randau', 'tua']]
r28 = [['hello']]
r29 = [['aku', 'nitihka', 'nuan', 'aja']]
r30 = [['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']]
r31 = [['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']]
r32 = [['aku', 'tusah', 'ati', 'enti', 'nuan', 'tusah', 'ati']]
r33 = [['aram', 'meh']]
r34 = [['ok', 'bye']]
#--------------------------------------------------------------------------------------------------------------------------------
c21 = ['ku', 'nuan', 'ka', 'nya', 'penyauh']
c22 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya']
c23 = ['nama', 'ku', 'chunto', 'adjektif', 'nya', 'jaku', 'meri', 'iya']
c24 = ['chunto', 'ayat', 'jaku', 'pengawa', 'diulang', 'pekakas', 'nya', 'beguaiguai']
c25 = ['jaku', 'bengkah', 'pengawa', 'iya', 'nya']
c26 = ['ulih', 'chunto', 'meri', 'perintah', 'jaku', 'nya']
c27 = ['no', 'response']
c28 = ['ulih', 'nuan', 'jaku', 'pasal', 'chunto']
c29 = ['nama', 'chunto', 'jaku']
c210 = ['jaku', 'nama', 'nya', 'enggau']
c211 = ['chunto', 'jaku', 'nama']
c212 = ['nama', 'jaku']
c213 = ['chunto', 'jaku', 'adjektif', 'nya']
c214 = ['chunto', 'jaku', 'nama']
c215 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya']
c216 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya', 'meri', 'iya']
c217 = ['meri', 'aku', 'chunto', 'jaku', 'adjektif', 'iya', 'nya']
c218 = ['nama', 'chunto', 'jaku', 'pengawa', 'nya']
c219 = ['nama', 'ku', 'jaku', 'pengawa', 'adjektif']
c220 = ['ulih', 'nuan', 'nerangka', 'ku', 'pasal', 'jaku', 'nama']
c221 = ['ulih', 'nuan', 'meri', 'aku', 'chunto', 'jaku', 'nya']
c222 = ['nama', 'bengkah', 'jaku', 'ngagai', 'tugas', 'iya']
c223 = ['kati', 'jaku', 'nama']
c224 = ['ku', 'nuan']
c225 = ['nama', 'ku', 'jaku', 'adjektif']
c226 = ['nuan', 'drama', 'siti', 'pharell', 'william']
c227 = ['nuan', 'ka', 'lagu', 'lalau', 'siti', 'ninga']
c228 = ['ku', 'nuan', 'ka', 'nya', 'penyauh']
c229 = ['uji', 'nuan', 'drama', 'peda', 'not', 'william']
c230 = ['kati', 'baka', 'jaku', 'nama', 'nya', 'deh', 'iya', 'enggau']
c231 = ['idup', 'ka', 'ninga', 'dudi', 'hari', 'direkomen', 'penenggau', 'gaga', 'pending']
c232 = ['cherita', 'cina', 'the', 'lagu', 'princess', 'pending', 'pansut', 'idup', 'tusah', 'ambih']
c233 = ['nama', 'chunto', 'jaku', 'nya', 'enggau']
c234 = ['nama', 'chunto', 'jaku', 'enggau']
smoothie = SmoothingFunction().method1

# 1 gram
s1 = sentence_bleu(r1, c21, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s2 = sentence_bleu(r2, c22, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s3 = sentence_bleu(r3, c23, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s4 = sentence_bleu(r4, c24, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s5 = sentence_bleu(r5, c25, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s6 = sentence_bleu(r6, c26, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s7 = sentence_bleu(r7, c27, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s8 = sentence_bleu(r8, c28, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s9 = sentence_bleu(r9, c29, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s10 = sentence_bleu(r10, c210, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s11 = sentence_bleu(r11, c211, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s12 = sentence_bleu(r12, c212, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s13 = sentence_bleu(r13, c213, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s14 = sentence_bleu(r14, c214, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s15 = sentence_bleu(r15, c215, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s16 = sentence_bleu(r16, c216, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s17 = sentence_bleu(r17, c217, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s18 = sentence_bleu(r18, c218, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s19 = sentence_bleu(r19, c219, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s20 = sentence_bleu(r20, c220, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s21 = sentence_bleu(r21, c221, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s22 = sentence_bleu(r22, c222, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s23 = sentence_bleu(r23, c223, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s24 = sentence_bleu(r24, c224, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s25 = sentence_bleu(r25, c225, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s26 = sentence_bleu(r26, c226, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s27 = sentence_bleu(r27, c227, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s28 = sentence_bleu(r28, c228, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s29 = sentence_bleu(r29, c229, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s30 = sentence_bleu(r30, c230, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s31 = sentence_bleu(r31, c231, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s32 = sentence_bleu(r32, c232, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s33 = sentence_bleu(r33, c233, smoothing_function=smoothie, weights=(1, 0, 0, 0))
s34 = sentence_bleu(r34, c234, smoothing_function=smoothie, weights=(1, 0, 0, 0))
# 2 gram
s11 = sentence_bleu(r1, c21, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s21 = sentence_bleu(r2, c22, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s31 = sentence_bleu(r3, c23, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s41 = sentence_bleu(r4, c24, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s51 = sentence_bleu(r5, c25, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s61 = sentence_bleu(r6, c26, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s71 = sentence_bleu(r7, c27, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s81 = sentence_bleu(r8, c28, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s91 = sentence_bleu(r9, c29, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s101 = sentence_bleu(r10, c210, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s111 = sentence_bleu(r11, c211, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s121 = sentence_bleu(r12, c212, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s131 = sentence_bleu(r13, c213, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s141 = sentence_bleu(r14, c214, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s151 = sentence_bleu(r15, c215, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s161 = sentence_bleu(r16, c216, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s171 = sentence_bleu(r17, c217, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s181 = sentence_bleu(r18, c218, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s191 = sentence_bleu(r19, c219, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s201 = sentence_bleu(r20, c220, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s211 = sentence_bleu(r21, c221, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s221 = sentence_bleu(r22, c222, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s231 = sentence_bleu(r23, c223, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s241 = sentence_bleu(r24, c224, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s251 = sentence_bleu(r25, c225, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s261 = sentence_bleu(r26, c226, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s271 = sentence_bleu(r27, c227, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s281 = sentence_bleu(r28, c228, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s291 = sentence_bleu(r29, c229, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s301 = sentence_bleu(r30, c230, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s311 = sentence_bleu(r31, c231, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s321 = sentence_bleu(r32, c232, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s331 = sentence_bleu(r33, c233, smoothing_function=smoothie, weights=(0, 1, 0, 0))
s341 = sentence_bleu(r34, c234, smoothing_function=smoothie, weights=(0, 1, 0, 0))

# 1 gram -----------------------------------------------------------------------------------------------------------------------------------------------------------
sa = s1 + s2 + s3 + s4 + s5 + s6 + s7 + s8 + s9 + s10 + s11 + s12 + s13 + s14 + s15 + s16 + s17
sb = s18 + s19 + s20 + s21 + s22 + s23 + s24 + s25 + s26 + s27 + s28 + s29 + s30 + s31 + s32 + s33 + s34
s = (sa + sb)/34

# 2 gram ------------------------------------------------------------------------------------------------------------------------------------------------------------
sa1 = s11 + s21 + s31 + s41 + s51 + s61 + s71 + s81 + s91 + s101 + s111 + s121 + s131 + s141 + s151 + s161 + s171
sb1 = s181 + s191 + s201 + s211 + s221 + s231 + s241 + s251 + s261 + s271 + s281 + s291 + s301 + s311 + s321 + s331 + s341
s2gram = (sa1 + sb1)/34
# print('Bleu Score: %f' % score)
print('Bleu Score 1-Gram Group 2 Seq2Seq: %f' % s)
print('Bleu Score 2-Gram Group 2 Seq2Seq: %f' % s2gram)
# Out:
# Bleu Score 1-Gram Group 2 Seq2Seq: 0.101459
# Bleu Score 2-Gram Group 2 Seq2Seq: 0.030160

# %%
#Bleu Evaluation Group 2 1-gram & 2-gram
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
#reference answer similar to Questionaire given to Human evaluators
reference1 = [['hi']]
reference2 = [['jaku', 'adjektif', 'tu', 'diguna', 'lebuh', 'deka', 'madahka', 'tauka', 'nyeritaka', 'jaku', 'nama']]
reference3 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'manah']]
reference4 = [['jaku', 'pengawa', 'dikena', 'ba', 'pugu', 'rambai', 'jaku', 'pengawa']]
reference5 = [['dua', 'bengkah', 'jaku', 'pengawa', 'iya', 'nya', 'jaku', 'pengawa', 'transitif', 'enggau', 'intrasitif']]
reference6 = [['sama', 'sama']]
reference7 = [['okay', 'sama', 'sama']]
reference8 = [['bahasa', 'iban', 'ngena', 'dua', 'puluh', 'enam', 'urup', 'roman', 'baka', 'bahasa', 'melayu']]
reference9 = [['raban', 'jaku', 'nya', 'dikena', 'nyebut', 'mensia', 'bansa', 'jelu', 'bansa', 'utai', 'tumbuh', 'bansa', 'indu', 'utai', 'nama', 'endur', 'nama', 'barang', 'enggau', 'ti', 'bukai']]
reference10 = [['jaku', 'nama', 'tetap', 'tu', 'nama', 'ti', 'diberi', 'ngagai', 'utai', 'idup', 'enda', 'ngira', 'iya', 'mensia', 'tauka', 'ukai', 'mensia']]
reference11 = [['chunto', 'jaku', 'nama', 'tetap', 'iya', 'nama', 'orang', 'baka', 'Listra']]
reference12 = [['minta', 'uji', 'enggau', 'anang']]
reference13 = [['nuan', 'ka', 'nemu', 'bengkah', 'jaku', 'nama', 'ni']]
reference14 = [['Bye']]
reference15 = [['antara', 'atur', 'sepil', 'jaku', 'iban', 'iya', 'atur', 'nulis', 'urat', 'jaku', 'atur', 'nulis', 'penambah', 'homograf', 'enggau', 'homonim']]
reference16 = [['chunto', 'leka', 'jaku', 'adjektif', 'iya', 'nya', 'pabu']]
reference17 = [['manah', 'amat', 'gamal', 'indu', 'nya']]
reference18 = [['jaku', 'penerang', 'pengawa', 'nya', 'jaku', 'ti', 'meri', 'penerang', 'ke', 'serap', 'agi', 'pasal', 'jaku', 'pengawa']]
reference19 = [['chunto', 'jaku', 'penerang', 'pengawa', 'iya', 'nya', 'beguai', 'guai']]
reference20 = [['jaku', 'tugas', 'semina', 'beguna', 'nyadika', 'sanding', 'jaku', 'nama']]
reference21 = [['sama', 'sama']]
reference22 = [['hi', 'mega']]
reference23 = [['aku', 'nitihka', 'nuan', 'aja']]
reference24 = [['aku', 'digaga', 'maya', 'taun', '2021']]
reference25 = [['cukup', 'cukup', 'kena', 'ku', 'ngerandau', 'nuan']]
reference26 = [['ilomilo', 'billie', 'ellish']]
reference27 = [['naka', 'tu', 'aja', 'randau', 'tua']]
reference28 = [['hello']]
reference29 = [['aku', 'nitihka', 'nuan', 'aja']]
reference30 = [['idup', 'ketegal', 'diri', 'empu', 'idup', 'meh', 'ketegal', 'orang', 'ti', 'sayauka', 'nuan']]
reference31 = [['anang', 'irau', 'nadai', 'ngawa', 'nuan', 'legi']]
reference32 = [['aku', 'tusah', 'ati', 'enti', 'nuan', 'tusah', 'ati']]
reference33 = [['aram', 'meh']]
reference34 = [['ok', 'bye']]

#--------------------------------------------------------------------------------------------------------------------------------
Candidate21 = ['ku', 'nuan', 'ka', 'nya', 'penyauh']
Candidate22 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya']
Candidate23 = ['nama', 'ku', 'chunto', 'adjektif', 'nya', 'jaku', 'meri', 'iya']
Candidate24 = ['chunto', 'ayat', 'jaku', 'pengawa', 'diulang', 'pekakas', 'nya', 'beguaiguai']
Candidate25 = ['jaku', 'bengkah', 'pengawa', 'iya', 'nya']
Candidate26 = ['ulih', 'chunto', 'meri', 'perintah', 'jaku', 'nya']
Candidate27 = ['no', 'response']
Candidate28 = ['ulih', 'nuan', 'jaku', 'pasal', 'chunto']
Candidate29 = ['nama', 'chunto', 'jaku']
Candidate210 = ['jaku', 'nama', 'nya', 'enggau']
Candidate211 = ['chunto', 'jaku', 'nama']
Candidate212 = ['nama', 'jaku']
Candidate213 = ['chunto', 'jaku', 'adjektif', 'nya']
Candidate214 = ['chunto', 'jaku', 'nama']
Candidate215 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya']
Candidate216 = ['nama', 'chunto', 'jaku', 'adjektif', 'nya', 'meri', 'iya']
Candidate217 = ['meri', 'aku', 'chunto', 'jaku', 'adjektif', 'iya', 'nya']
Candidate218 = ['nama', 'chunto', 'jaku', 'pengawa', 'nya']
Candidate219 = ['nama', 'ku', 'jaku', 'pengawa', 'adjektif']
Candidate220 = ['ulih', 'nuan', 'nerangka', 'ku', 'pasal', 'jaku', 'nama']
Candidate221 = ['ulih', 'nuan', 'meri', 'aku', 'chunto', 'jaku', 'nya']
Candidate222 = ['nama', 'bengkah', 'jaku', 'ngagai', 'tugas', 'iya']
Candidate223 = ['kati', 'jaku', 'nama']
Candidate224 = ['ku', 'nuan']
Candidate225 = ['nama', 'ku', 'jaku', 'adjektif']
Candidate226 = ['nuan', 'drama', 'siti', 'pharell', 'william']
Candidate227 = ['nuan', 'ka', 'lagu', 'lalau', 'siti', 'ninga']
Candidate228 = ['ku', 'nuan', 'ka', 'nya', 'penyauh']
Candidate229 = ['uji', 'nuan', 'drama', 'peda', 'not', 'william']
Candidate230 = ['kati', 'baka', 'jaku', 'nama', 'nya', 'deh', 'iya', 'enggau']
Candidate231 = ['idup', 'ka', 'ninga', 'dudi', 'hari', 'direkomen', 'penenggau', 'gaga', 'pending']
Candidate232 = ['cherita', 'cina', 'the', 'lagu', 'princess', 'pending', 'pansut', 'idup', 'tusah', 'ambih']
Candidate233 = ['nama', 'chunto', 'jaku', 'nya', 'enggau']
Candidate234 = ['nama', 'chunto', 'jaku', 'enggau']
smoothie = SmoothingFunction().method1

# 3 gram
score1 = sentence_bleu(reference1, Candidate21, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score2 = sentence_bleu(reference2, Candidate22, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score3 = sentence_bleu(reference3, Candidate23, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score4 = sentence_bleu(reference4, Candidate24, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score5 = sentence_bleu(reference5, Candidate25, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score6 = sentence_bleu(reference6, Candidate26, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score7 = sentence_bleu(reference7, Candidate27, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score8 = sentence_bleu(reference8, Candidate28, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score9 = sentence_bleu(reference9, Candidate29, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score10 = sentence_bleu(reference10, Candidate210, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score11 = sentence_bleu(reference11, Candidate211, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score12 = sentence_bleu(reference12, Candidate212, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score13 = sentence_bleu(reference13, Candidate213, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score14 = sentence_bleu(reference14, Candidate214, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score15 = sentence_bleu(reference15, Candidate215, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score16 = sentence_bleu(reference16, Candidate216, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score17 = sentence_bleu(reference17, Candidate217, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score18 = sentence_bleu(reference18, Candidate218, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score19 = sentence_bleu(reference19, Candidate219, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score20 = sentence_bleu(reference20, Candidate220, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score21 = sentence_bleu(reference21, Candidate221, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score22 = sentence_bleu(reference22, Candidate222, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score23 = sentence_bleu(reference23, Candidate223, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score24 = sentence_bleu(reference24, Candidate224, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score25 = sentence_bleu(reference25, Candidate225, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score26 = sentence_bleu(reference26, Candidate226, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score27 = sentence_bleu(reference27, Candidate227, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score28 = sentence_bleu(reference28, Candidate228, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score29 = sentence_bleu(reference29, Candidate229, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score30 = sentence_bleu(reference30, Candidate230, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score31 = sentence_bleu(reference31, Candidate231, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score32 = sentence_bleu(reference32, Candidate232, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score33 = sentence_bleu(reference33, Candidate233, smoothing_function=smoothie, weights=(0, 0, 1, 0))
score34 = sentence_bleu(reference34, Candidate234, smoothing_function=smoothie, weights=(0, 0, 1, 0))
# 4 gram
score11 = sentence_bleu(reference1, Candidate21, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score21 = sentence_bleu(reference2, Candidate22, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score31 = sentence_bleu(reference3, Candidate23, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score41 = sentence_bleu(reference4, Candidate24, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score51 = sentence_bleu(reference5, Candidate25, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score61 = sentence_bleu(reference6, Candidate26, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score71 = sentence_bleu(reference7, Candidate27, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score81 = sentence_bleu(reference8, Candidate28, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score91 = sentence_bleu(reference9, Candidate29, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score101 = sentence_bleu(reference10, Candidate210, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score111 = sentence_bleu(reference11, Candidate211, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score121 = sentence_bleu(reference12, Candidate212, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score131 = sentence_bleu(reference13, Candidate213, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score141 = sentence_bleu(reference14, Candidate214, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score151 = sentence_bleu(reference15, Candidate215, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score161 = sentence_bleu(reference16, Candidate216, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score171 = sentence_bleu(reference17, Candidate217, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score181 = sentence_bleu(reference18, Candidate218, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score191 = sentence_bleu(reference19, Candidate219, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score201 = sentence_bleu(reference20, Candidate220, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score211 = sentence_bleu(reference21, Candidate221, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score221 = sentence_bleu(reference22, Candidate222, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score231 = sentence_bleu(reference23, Candidate223, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score241 = sentence_bleu(reference24, Candidate224, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score251 = sentence_bleu(reference25, Candidate225, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score261 = sentence_bleu(reference26, Candidate226, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score271 = sentence_bleu(reference27, Candidate227, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score281 = sentence_bleu(reference28, Candidate228, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score291 = sentence_bleu(reference29, Candidate229, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score301 = sentence_bleu(reference30, Candidate230, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score311 = sentence_bleu(reference31, Candidate231, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score321 = sentence_bleu(reference32, Candidate232, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score331 = sentence_bleu(reference33, Candidate233, smoothing_function=smoothie, weights=(0, 0, 0, 1))
score341 = sentence_bleu(reference34, Candidate234, smoothing_function=smoothie, weights=(0, 0, 0, 1))

# 3 gram -----------------------------------------------------------------------------------------------------------------------------------------------------------
scorea = score1 + score2 + score3 + score4 + score5 + score6 + score7 + score8 + score9 + score10 + score11 + score12 + score13 + score14 + score15 + score16 + score17
scoreb = score18 + score19 + score20 + score21 + score22 + score23 + score24 + score25 + score26 + score27 + score28 + score29 + score30 + score31 + score32 + score33 + score34
score = (scorea + scoreb)/34

# 4 gram ------------------------------------------------------------------------------------------------------------------------------------------------------------
scorea1 = score11 + score21 + score31 + score41 + score51 + score61 + score71 + score81 + score91 + score101 + score111 + score121 + score131 + score141 + score151 + score161 + score171
scoreb1 = score181 + score191 + score201 + score211 + score221 + score231 + score241 + score251 + score261 + score271 + score281 + score291 + score301 + score311 + score321 + score331 + score341
score2gram = (scorea1 + scoreb1)/34
# print('Bleu Score: %f' % score)
print('Bleu Score 3-Gram Group 2 Seq2Seq: %f' % score)
print('Bleu Score 4-Gram Group 2 Seq2Seq: %f' % score2gram)
# Out:
# Bleu Score 3-Gram Group 2 Seq2Seq: 0.010509
# Bleu Score 4-Gram Group 2 Seq2Seq: 0.010477
